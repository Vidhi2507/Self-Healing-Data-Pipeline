# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Reading the file
df = pd.read_csv("data_check.csv")
df.head()
# Out:
#    ParticipantID FirstName LastName         DOB                Email  \
# 0              1     Alice  Johnson  1998-05-12    alice@example.com
# 1              2       Bob    Smith  2000-11-03      bob@example.com
# 2              3   Charlie       Wu  1999-02-20  charlie@example.com
# 3              4     Deepa     Shah  2001-07-14    deepa@example.com
# 4              5     Ethan    Brown  1997-09-01    ethan@example.com
#
#         TeamName         ProjectTitle     Category
# 0     Team Alpha  Smart Recycling Bin  Environment
# 1     Team Alpha  Smart Recycling Bin  Environment
# 2  Team Innovate   Health Tracker App       Health
# 3    Team Vision   AI Traffic Monitor   Smart City
# 4  Team CodeWave            FinAssist     Business

# %%
today = pd.Timestamp.now()
df["Age"] = df["DOB"].apply(lambda dob: today - pd.to_datetime(dob)).dt.days // 365
df.head()
# Out:
#    ParticipantID FirstName LastName         DOB                Email  \
# 0              1     Alice  Johnson  1998-05-12    alice@example.com
# 1              2       Bob    Smith  2000-11-03      bob@example.com
# 2              3   Charlie       Wu  1999-02-20  charlie@example.com
# 3              4     Deepa     Shah  2001-07-14    deepa@example.com
# 4              5     Ethan    Brown  1997-09-01    ethan@example.com
#
#         TeamName         ProjectTitle     Category  Age
# 0     Team Alpha  Smart Recycling Bin  Environment   27
# 1     Team Alpha  Smart Recycling Bin  Environment   25
# 2  Team Innovate   Health Tracker App       Health   26
# 3    Team Vision   AI Traffic Monitor   Smart City   24
# 4  Team CodeWave            FinAssist     Business   28

# %%
team_counts = df["TeamName"].value_counts()
print(team_counts)
# Out:
# TeamName
# Team Alpha       4
# Team Innovate    4
# Team Vision      4
# Team CodeWave    4
# Team Builders    4
# Name: count, dtype: int64

# %%
avg_age_by_team = df.groupby("TeamName")["Age"].mean()
print(avg_age_by_team)
# Out:
# TeamName
# Team Alpha       25.75
# Team Builders    24.25
# Team CodeWave    26.50
# Team Innovate    26.50
# Team Vision      25.00
# Name: Age, dtype: float64

# %%
plt.figure(figsize=(8,5))
plt.hist(df["Age"], bins=8, color="skyblue", edgecolor="black")
plt.title("Age Distribution of Participants")
plt.xlabel("Age")
plt.ylabel("Number of Participants")
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# %%
plt.figure(figsize=(8,5))
df["TeamName"].value_counts().plot(kind='bar', color='lightgreen', edgecolor='black')
plt.title("Participants Per Team")
plt.xlabel("Team")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,5))
df["Category"].value_counts().plot(kind='bar', color='salmon', edgecolor='black')
plt.title("Participants by Category")
plt.xlabel("Category")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.boxplot(df["Age"], patch_artist=True, boxprops=dict(facecolor="lavender"))
plt.title("Age Spread (Box Plot)")
plt.ylabel("Age")
plt.show()
